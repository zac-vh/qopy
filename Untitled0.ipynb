# %% [markdown]
# <a href="https://colab.research.google.com/github/zac-vh/qopy/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cloner le dépôt
#!git clone https://github.com/zac-vh/qopy.git

# Ajouter le dossier src au PYTHONPATH
import sys
sys.path.append('/content/qopy/src')

import qopy.phase_space.wigner as wig
import qopy.plotting as wplot

# Exemple d'utilisation
rl = 10
nr = 1000
w = wig.wigner_fock(1, rl, nr)
gamma = 1
disp = (0, -3)
sq = 1.5
wcubic = wig.wigner_cubic_phase(gamma, rl, nr, disp, sq)

wplot.plot_2d([w, wcubic], rl)
